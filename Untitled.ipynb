# %%
import pandas as pd

# %%
m = pd.read_csv('./ICD-10 mappings.csv')

# %%
df = pd.read_csv('.Data/data_LACE_not_scored.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-a45cb27275c3> in <module>
# ----> 1 df = pd.read_csv('.Data/data_LACE_not_scored.csv')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'.Data/data_LACE_not_scored.csv' does not exist: b'.Data/data_LACE_not_scored.csv'

# %%
m
# Out:
#    Myocardial infarction Congestive heart failure Peripheral vascular disease  \
# 0                  I21.x                    I09.9                       I70.x
# 1                  I22.x                    I11.0                       I71.x
# 2                  I25.2                    I13.0                       I73.1
# 3                    NaN                    I13.2                       I73.8
# 4                    NaN                    I25.5                       I73.9
# 5                    NaN                    I42.0                       I77.1
# 6                    NaN                    I42.5                       I79.0
# 7                    NaN                    I42.6                       I79.2
# 8                    NaN                    I42.7                       K55.1
# 9                    NaN                    I42.8                       K55.8
# 10                   NaN                    I42.9                       K55.9
# 11                   NaN                    I43.x                       Z95.8
# 12                   NaN                    I50.x                       Z95.9
# 13                   NaN                    P29.0                         NaN
# 14                   NaN                      NaN                         NaN
# 15                   NaN                      NaN                         NaN
# 16                   NaN                      NaN                         NaN
# 17                   NaN                      NaN                         NaN
# 18                   NaN                      NaN                         NaN
# 19                   NaN                      NaN                         NaN
# 20                   NaN                      NaN                         NaN
# 21                   NaN                      NaN                         NaN
# 22                   NaN                      NaN                         NaN
# 23                   NaN                      NaN                         NaN
# 24                   NaN                      NaN                         NaN
#
#    Cerebrovascular disease Dementia Chronic pulmonary disease  \
# 0                    G45.x    F00.x                     I27.8
# 1                    G46.x    F02.x                     I27.9
# 2                    H34.0    F03.x                     J40.x
# 3                    I60.x    F05.1                     J41.x
# 4                    162.x    G30.x                     J42.x
# 5                    163.x    G31.1                     J43.x
# 6                    164.x      NaN                     J44.x
# 7                    165.x      NaN                     J45.x
# 8                    166.x      NaN                     J46.x
# 9                    167.x      NaN                     J47.x
# 10                   168.x      NaN                     J60.x
# 11                   I69.x      NaN                     J61.x
# 12                     NaN      NaN                     J62.x
# 13                     NaN      NaN                     J63.x
# 14                     NaN      NaN                     J64.x
# 15                     NaN      NaN                     J65.x
# 16                     NaN      NaN                     J66.x
# 17                     NaN      NaN                     J67.x
# 18                     NaN      NaN                     J68.4
# 19                     NaN      NaN                     J70.1
# 20                     NaN      NaN                     J70.3
# 21                     NaN      NaN                       NaN
# 22                     NaN      NaN                       NaN
# 23                     NaN      NaN                       NaN
# 24                     NaN      NaN                       NaN
#
#    Rheumatic disease Peptic ulcer disease Mild liver disease  \
# 0              M05.x                K25.x              B18.x
# 1              M06.x                K26.x              K70.0
# 2              M31.5                K27.x              K70.1
# 3              M32.x                K28.x              K70.2
# 4              M33.x                  NaN              K70.3
# 5              M34.x                  NaN              K70.9
# 6              M35.1                  NaN              K71.3
# 7              M35.3                  NaN              K71.4
# 8              M36.0                  NaN              K71.5
# 9                NaN                  NaN              K71.7
# 10               NaN                  NaN              K73.x
# 11               NaN                  NaN              K74.x
# 12               NaN                  NaN              K76.0
# 13               NaN                  NaN              K76.2
# 14               NaN                  NaN              K76.3
# 15               NaN                  NaN              K76.4
# 16               NaN                  NaN              K76.8
# 17               NaN                  NaN              K76.9
# 18               NaN                  NaN              Z94.4
# 19               NaN                  NaN                NaN
# 20               NaN                  NaN                NaN
# 21               NaN                  NaN                NaN
# 22               NaN                  NaN                NaN
# 23               NaN                  NaN                NaN
# 24               NaN                  NaN                NaN
#
#    Diabetes without chronic complication Diabetes with chronic complication  \
# 0                                  E10.0                              E10.2
# 1                                  E10.l                              E10.3
# 2                                  E10.6                              E10.4
# 3                                  E10.8                              E10.5
# 4                                  E10.9                              E10.7
# 5                                  E11.0                              E11.2
# 6                                  E11.1                              E11.3
# 7                                  E11.6                              E11.4
# 8                                  E11.8                              E11.5
# 9                                  E11.9                              E11.7
# 10                                 E12.0                              E12.2
# 11                                 E12.1                              E12.3
# 12                                 E12.6                              E12.4
# 13                                 E12.8                              E12.5
# 14                                 E12.9                              E12.7
# 15                                 E13.0                              E13.2
# 16                                 E13.1                              E13.3
# 17                                 E13.6                              E13.4
# 18                                 E13.8                              E13.5
# 19                                 E13.9                              E13.7
# 20                                 E14.0                              E14.2
# 21                                 E14.1                              E14.3
# 22                                 E14.6                              E14.4
# 23                                 E14.8                              E14.5
# 24                                 E14.9                              E14.7
#
#    Hemiplegia or paraplegia  \
# 0                     G04.1
# 1                     G11.4
# 2                     G80.1
# 3                     G80.2
# 4                     G81.x
# 5                     G82.x
# 6                     G83.0
# 7                     G83.1
# 8                     G83.2
# 9                     G83.3
# 10                    G83.4
# 11                    G83.9
# 12                      NaN
# 13                      NaN
# 14                      NaN
# 15                      NaN
# 16                      NaN
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21                      NaN
# 22                      NaN
# 23                      NaN
# 24                      NaN
#
#    Any tumor lymphoma and leukemia, except malignant neoplasm of skin  \
# 0                                         C00.x-C26.x
# 1                                         C30.x-C34.x
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
#
#    Renal disease Moderate or severe liver disease Metastatic solid tumor  \
# 0          I12.0                            I85.0                  C77.x
# 1          I13.1                            I85.9                  C78.x
# 2          N03.2                            I86.4                  C79.x
# 3          N03.3                            I98.2                  C80.x
# 4          N03.4                            K70.4                    NaN
# 5          N03.5                            K71.1                    NaN
# 6          N03.6                            K72.1                    NaN
# 7          N03.7                            K72.9                    NaN
# 8          N05.2                            K76.5                    NaN
# 9          N05.3                            K76.6                    NaN
# 10         N05.4                              NaN                    NaN
# 11         N05.5                              NaN                    NaN
# 12         N05.6                              NaN                    NaN
# 13         N05.7                              NaN                    NaN
# 14         N18.x                              NaN                    NaN
# 15         N19.x                              NaN                    NaN
# 16         N25.0                              NaN                    NaN
# 17         Z49.0                              NaN                    NaN
# 18         Z49.1                              NaN                    NaN
# 19         Z49.2                              NaN                    NaN
# 20         Z94.0                              NaN                    NaN
# 21         Z99.2                              NaN                    NaN
# 22           NaN                              NaN                    NaN
# 23           NaN                              NaN                    NaN
# 24           NaN                              NaN                    NaN
#
#    AIDS/HIV
# 0     B20.x
# 1     B21.x
# 2     B22.x
# 3     B24.x
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN

# %%
m.columns.tolist()
# Out:
# ['Myocardial infarction',
#  'Congestive heart failure',
#  'Peripheral vascular disease',
#  'Cerebrovascular disease',
#  'Dementia',
#  'Chronic pulmonary disease',
#  'Rheumatic disease',
#  'Peptic ulcer disease',
#  'Mild liver disease',
#  'Diabetes without chronic complication',
#  'Diabetes with chronic complication',
#  'Hemiplegia or paraplegia',
#  'Any tumor lymphoma and leukemia, except malignant neoplasm of skin',
#  'Renal disease',
#  'Moderate or severe liver disease',
#  'Metastatic solid tumor',
#  'AIDS/HIV']

# %%
m['Any tumor lymphoma and leukemia, except malignant neoplasm of skin']
# Out:
# 25

# %%
type(m['Score'])
# Out:
# pandas.core.series.Series

# %%
a = {1:2, 3:4, 5:6}

# %%
a.values()
# Out:
# dict_values([2, 4, 6])
